# %% [markdown]
# # Data set from Google Trends

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import numpy as np
import html
import matplotlib.pyplot as plt
from matplotlib.ticker import PercentFormatter
import seaborn as sns
sns.set()

# %%
data_ = pd.read_csv('geoMap.csv')
data_
# Out:
#            Region  medicine shops
# 0     West Bengal             100
# 1           Delhi              95
# 2       Telangana              90
# 3  Andhra Pradesh              71
# 4       Karnataka              59
# 5      Tamil Nadu              50
# 6     Maharashtra              40
# 7   Uttar Pradesh              26

# %%
data_ = pd.read_csv('geoMap.csv')
data_

fig, ax = plt.subplots(figsize = (10, 7))

ax.bar(data_["Region"],
       data_["medicine shops"],
       color = "r")
ax.set_ylabel("Number of Participants",
             weight = "bold")
ax.tick_params(axis = "y",
               width = 2,
               labelsize = "large")
